# %%
import sys,os
sys.path.append(os.path.abspath("../src"))

import glob
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt


# %load_ext autoreload
# %autoreload 1
import data_cleaner
# %aimport data_cleaner
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
image_paths = glob.glob("../data/*.png")

# %%
ind = 20
test_img = data_cleaner.crop_and_resize(image_paths[ind], padding=5, target_size=(64,64))
img = Image.open(image_paths[ind]).convert("RGBA")
# Out:
# muy bien!

# %%
plt.figure()
plt.subplot(1,2,1)
plt.imshow(img)
plt.title("original")
plt.subplot(1,2,2)
plt.imshow(test_img)
plt.title("crop+resize")
# Out:
# Text(0.5, 1.0, 'crop+resize')

# %%
dest_path = "../data/preprocessed"
for file in image_paths:
    new_path = os.path.join(dest_path,os.path.basename(file))
    preproc_img = data_cleaner.crop_and_resize(file, padding=5, target_size=(64,64))
    preproc_img.save(new_path)
